# %%
# !pip install contextily
# !pip install pyrsgis
# Out:
# Collecting contextily
#   Downloading contextily-1.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.7.1)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (8.4.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.3.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 48.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.27.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.3.1)
# Collecting xyzservices (from contextily)
#   Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile->contextily) (8.1.4)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2023.5.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->contextily)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (67.7.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (1.26.16)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Installing collected packages: xyzservices, snuggs, mercantile, affine, rasterio, contextily
# Successfully installed affine-2.4.0 contextily-1.3.0 mercantile-1.2.1 rasterio-1.3.8 snuggs-1.4.7 xyzservices-2023.7.0
# Collecting pyrsgis
#   Downloading pyrsgis-0.4.1-py3-none-any.whl (25 kB)
# Installing collected packages: pyrsgis
# Successfully installed pyrsgis-0.4.1

# %%
import contextily as cx
from ipywidgets import interact
from math import floor
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter, MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import pandas as pd
from pyrsgis import raster
from pyrsgis.convert import array_to_table
from pyrsgis.ml import imageChipsFromArray
import random
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import SVC
from statistics import mean
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# file names
feature_file = '/content/drive/MyDrive/Nadi_2013/2013_NDVI_NDWI_NDBI.tif'
# read the image
dsFeatures, arrFeatures = raster.read(feature_file, bands='all')
min_x = dsFeatures.bbox[0][0]
max_x = dsFeatures.bbox[1][0]
min_y = dsFeatures.bbox[0][1]
max_y = dsFeatures.bbox[1][1]

extent = [min_x, max_x, min_y, max_y]

# %%
extent
# Out:
# [177.35465603830238,
#  177.5796840169743,
#  -17.874497860353415,
#  -17.66024966509091]

# %%
arrFeatures.shape
# Out:
# (10, 795, 835)

# %%
import copy
from copy import deepcopy
from sklearn.feature_extraction import image

# %%
def imageChipsFromSingleBandArray(data_arr, y_size=5, x_size=5):
    image_chips = deepcopy(data_arr)
    image_chips = np.pad(image_chips, (int(y_size/2),int(x_size/2)), 'reflect')
    image_chips = image.extract_patches_2d(image_chips, (y_size, x_size))

    return(image_chips)
def imageChipsFromArray_update(data_array, x_size=5, y_size=5):

    # if array is a single band image
    if len(data_array.shape) == 2:
        return(imageChipsFromSingleBandArray(data_array, x_size=x_size, y_size=y_size))

    # if array is a multi band image
    elif len(data_array.shape) > 2:
        data_array = copy.copy(data_array)
        data_array = np.rollaxis(data_array, 0, 3)

        for band in range(data_array.shape[2]):
            temp_array = imageChipsFromSingleBandArray(data_array[:, :, band], x_size=x_size, y_size=y_size)

            if band == 0:
                out_array = np.expand_dims(temp_array, axis=3)
            else:
                out_array = np.concatenate((out_array, np.expand_dims(temp_array, axis=3)), axis=3)

        return(out_array)

    # if shape of the image is less than two dimensions, raise error
    else:
        raise Exception("Sorry, only two or three dimensional arrays allowed.")

# %%
# normalize the image and generate chips
arrFeatures_fuzzy = np.zeros(arrFeatures.shape)

for i in range(arrFeatures.shape[0]):
    bandMin = arrFeatures[i, :, :].min()
    bandMax = arrFeatures[i, :, :].max()
    bandRange = bandMax-bandMin
    for j in range(arrFeatures.shape[1]):
        for k in range(arrFeatures.shape[2]):
            arrFeatures_fuzzy[i, j, k] = (arrFeatures[i, j, k]-bandMin)/bandRange

#create chips using pyrsgis
#features_chips = imageChipsFromArray(arrFeatures_fuzzy, x_size=7, y_size=7)
features_chips = imageChipsFromArray_update(arrFeatures_fuzzy, x_size=9, y_size=9)

# %%
features_chips.shape
# Out:
# (663825, 9, 9, 10)

# %% [markdown]
# *****

# %% [markdown]
# **2013_Training datast**

# %%
positiveLabel_file = '/content/drive/MyDrive/Nadi_2013/Label_2013_1117.tif'
dsPositiveLabels, arrPositiveLabels = raster.read(positiveLabel_file,bands='all')
n_class_pos = len(np.unique(arrPositiveLabels))

# %%
n_class_pos
# Out:
# 8

# %%
arrPositiveLabels=arrPositiveLabels+1
np.unique(arrPositiveLabels)
# Out:
# array([0., 1., 2., 3., 4., 5., 6., 7.])

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels)
index = np.transpose(np.where(arrPositiveLabels==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class

arrPositiveLabels_flat = arrPositiveLabels.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = features_chips[arrPositiveLabels_flat!=0]
positiveLabels = arrPositiveLabels_flat[arrPositiveLabels_flat!=0]

features=positiveFeatures
labels=positiveLabels

# %%
 len(features_chips[arrPositiveLabels_flat==6])
# Out:
# 91

# %%
from sklearn.utils import resample
coastal_upsample = resample(features_chips[arrPositiveLabels_flat==6],
             replace=True,
             n_samples=159,
             random_state=42)

# %%
arr = np.concatenate((features, coastal_upsample), axis=0)

# %%
features=arr
coastal_label=[6]*159
new_label=np.concatenate((labels,coastal_label),axis=0)
labels=new_label
labels=labels-1

# %%
n_class_pos = len(np.unique(labels))
print(n_class_pos)
# Out:
# 7

# %%
labels_df=pd.DataFrame()
labels_df['labels']=labels
labels_df['labels'].value_counts()
# Out:
# 2.0    250
# 4.0    250
# 1.0    250
# 6.0    250
# 0.0    250
# 5.0    250
# 3.0    250
# Name: labels, dtype: int64

# %% [markdown]
# ****

# %% [markdown]
# **Split**

# %%
# # define a function to split features and labels
def train_test_split(features, labels, n_class_pos=n_class_pos, trainProp=0.7):
    labels_df=pd.DataFrame()
    labels_df['labels']=labels
    labels_df.reset_index(inplace=True)
    labels_df['labels']=labels_df['labels'].astype(int)

    train_list=[]
    test_list=[]
    for class_index in range(n_class_pos):
      sub_labels_df=labels_df[labels_df['labels'] == class_index ]
      dataSize=len(sub_labels_df['index'])
      sliceIndex = int(dataSize*trainProp)
      randIndex = list(sub_labels_df['index'])
      #random.seed(45)
      random.shuffle(randIndex)

      sub_train_list=randIndex[:sliceIndex]
      train_list = train_list + sub_train_list

      sub_test_list=randIndex[sliceIndex:]
      test_list = test_list + sub_test_list

    train_x = features[[train_list], :, :, :][0]
    test_x = features[[test_list], :, :, :][0]
    train_y = labels[train_list]
    test_y = labels[test_list]
    return(train_x, train_y, test_x, test_y)

# call the function to split the dataset
train_x, train_y, test_x, test_y = train_test_split(features, labels)

# %%
train_y_df=pd.DataFrame()
train_y_df['labels']=train_y
train_y_df['labels'].value_counts()
# Out:
# 0.0    175
# 1.0    175
# 2.0    175
# 3.0    175
# 4.0    175
# 5.0    175
# 6.0    175
# Name: labels, dtype: int64

# %%
test_y_df=pd.DataFrame()
test_y_df['labels']=test_y
test_y_df['labels'].value_counts()
# Out:
# 0.0    75
# 1.0    75
# 2.0    75
# 3.0    75
# 4.0    75
# 5.0    75
# 6.0    75
# Name: labels, dtype: int64

# %% [markdown]
# ****

# %%
175*7
# Out:
# 1225

# %% [markdown]
# **Model**

# %%
from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# %%
print(f"train_x.shape: {train_x.shape}")
print(f"train_y.shape: {train_y.shape}")
print(f"test_x.shape: {test_x.shape}")
print(f"test_y.shape: {test_y.shape}")
# Out:
# train_x.shape: (1225, 9, 9, 10)
# train_y.shape: (1225,)
# test_x.shape: (525, 9, 9, 10)
# test_y.shape: (525,)

# %%
X_train_mlp = train_x.reshape((1225, 9*9*10))
X_test_mlp = test_x.reshape((525, 9*9*10))
y_train_mlp = to_categorical(train_y)
y_test_mlp = to_categorical(test_y)

# %%
def roc_auc(model, X_test_mlp, y_test_mlp, n_classes):
    roc_auc = []
    test_z = model.predict(X_test_mlp)
    test_y_dummies = y_test_mlp

    for i in range(n_classes):
        roc_auc.append(roc_auc_score(test_y_dummies[:, i], test_z[:, i]))

    return roc_auc

# %%
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics)+1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and Testing '+metric.capitalize())
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend(['Training '+metric.capitalize(), 'Testing '+metric.capitalize()])
    plt.show()

# %% [markdown]
# *****

# %% [markdown]
# ****

# %%
def roc_plot(test_y, test_z, n_classes, labels_name, average='macro'):
    fpr = {}
    tpr = {}
    roc_auc = {}

    test_y_dummies = y_test_mlp
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_y_dummies[:, i], test_z[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    # roc for each class
    fig, ax = plt.subplots()
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver Operating Characteristic')

    for i in range(n_classes):
        ax.plot(fpr[i], tpr[i], label='{}, AUC = {}'.format(labels_name[i], '{0:.4f}'.format(roc_auc[i])))

    ax.legend(loc='best')
    ax.grid(alpha=0.5)
    sns.despine()
    plt.show()
    print('ROC AUC score:', roc_auc_score(test_y_dummies, test_z, average=average))

best_model = tf.keras.models.Sequential()
best_accuracy = 0
best_history = None

experimental_runs = 10
cv = 10
metrics_columns = ['Accuracy', 'Precision', 'Recall', 'F1 Score','AUC_Urban','AUC_Crop/Grass','AUC_Trees','AUC_Bare','AUC_Water','AUC_Coastal','AUC_wetland','Roc_auc_mean']
temp_metrics_df = pd.DataFrame(np.zeros((cv, len(metrics_columns))), columns=metrics_columns)

################################### Model ###################################################

for i in range(experimental_runs):

    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(X_train_mlp.shape[1], )))

    model.add(tf.keras.layers.Dense(32, activation='relu'))


    model.add(tf.keras.layers.Dense(7, activation='softmax'))

    model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
    history=model.fit(X_train_mlp, y_train_mlp, epochs=100, batch_size=32, validation_data=(X_test_mlp, y_test_mlp))


    for j in range(cv):

        test_z = model.predict(X_test_mlp)
        test_z_class = test_z.argmax(axis=1)

        aScore = accuracy_score(test_y, test_z_class)
        pScore = precision_score(test_y, test_z_class, average='macro')
        rScore = recall_score(test_y, test_z_class, average='macro')
        fScore = f1_score(test_y, test_z_class, average='macro')
        cMatrix = confusion_matrix(test_y, test_z_class)
        metrics_array = [aScore, pScore, rScore, fScore]

        roc_auc_class = roc_auc(model, X_test_mlp, y_test_mlp, n_class_pos)



        for k in range(n_class_pos):
            metrics_array.append(roc_auc_class[k])

        roc_auc_mean = mean(roc_auc_class)
        metrics_array.append(roc_auc_mean)
        temp_metrics_df.loc[j] = metrics_array
        if j==cv-1:
            # accuracy can be replaced with other scores
            aScore_avg = temp_metrics_df['Accuracy'].mean()

            if best_accuracy < aScore_avg:
                best_model = model
                best_accuracy_avg = aScore_avg
                best_history = history

print(f'\nBest Average Accuracy: {best_accuracy_avg}')
test_z = best_model.predict(X_test_mlp)

roc_auc_class = roc_auc(model, X_test_mlp, y_test_mlp,n_class_pos)
metrics_array.extend(roc_auc_class)
roc_auc_mean = mean(roc_auc_class)
metrics_array.append(roc_auc_mean)

print(f'\nConfusion Matrix:\n{cMatrix}')
print(f'\nAccuracy: {aScore}')
print(f'\nPrecision: {pScore}')
print(f'\nRecall: {rScore}')
print(f'\nF1 Score: {fScore}')

plot_metric(history, 'loss')
print('')
plot_metric(history, 'accuracy')


labels_name = ['Urban','Crop/Grass','Trees','Bare','Water','Coastal','wetland'] #Labels name should be the same with the class
roc_plot(test_y, test_z, n_class_pos, labels_name)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 2s 16ms/step - loss: 1.6415 - accuracy: 0.4294 - val_loss: 1.4433 - val_accuracy: 0.5657
# Epoch 2/100
# 39/39 [==============================] - 0s 8ms/step - loss: 1.3079 - accuracy: 0.5812 - val_loss: 1.1798 - val_accuracy: 0.6343
# Epoch 3/100
# 39/39 [==============================] - 0s 8ms/step - loss: 1.1049 - accuracy: 0.6392 - val_loss: 1.0238 - val_accuracy: 0.6800
# Epoch 4/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.9742 - accuracy: 0.6702 - val_loss: 0.9236 - val_accuracy: 0.7067
# Epoch 5/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.8626 - accuracy: 0.7404 - val_loss: 0.8300 - val_accuracy: 0.7695
# Epoch 6/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.7989 - accuracy: 0.7543 - val_loss: 0.7541 - val_accuracy: 0.7562
# Epoch 7/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.7443 - accuracy: 0.7543 - val_loss: 0.7373 - val_accuracy: 0.6838
# Epoch 8/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.7039 - accuracy: 0.7592 - val_loss: 0.6896 - val_accuracy: 0.7733
# Epoch 9/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6705 - accuracy: 0.7771 - val_loss: 0.6461 - val_accuracy: 0.8095
# Epoch 10/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6320 - accuracy: 0.7739 - val_loss: 0.6172 - val_accuracy: 0.7867
# Epoch 11/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6170 - accuracy: 0.7869 - val_loss: 0.6185 - val_accuracy: 0.7733
# Epoch 12/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6085 - accuracy: 0.7747 - val_loss: 0.5869 - val_accuracy: 0.7810
# Epoch 13/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.5580 - accuracy: 0.8147 - val_loss: 0.5704 - val_accuracy: 0.7886
# Epoch 14/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.5481 - accuracy: 0.8082 - val_loss: 0.5519 - val_accuracy: 0.8057
# Epoch 15/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5205 - accuracy: 0.8163 - val_loss: 0.5309 - val_accuracy: 0.8400
# Epoch 16/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5095 - accuracy: 0.8253 - val_loss: 0.5112 - val_accuracy: 0.8057
# Epoch 17/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.4848 - accuracy: 0.8424 - val_loss: 0.4919 - val_accuracy: 0.8248
# Epoch 18/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.4683 - accuracy: 0.8392 - val_loss: 0.4977 - val_accuracy: 0.8476
# Epoch 19/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.
100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.3029 - accuracy: 0.9151 - val_loss: 0.3136 - val_accuracy: 0.9029
# Epoch 44/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2941 - accuracy: 0.9192 - val_loss: 0.3188 - val_accuracy: 0.8952
# Epoch 45/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2912 - accuracy: 0.9159 - val_loss: 0.3012 - val_accuracy: 0.9105
# Epoch 46/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2833 - accuracy: 0.9167 - val_loss: 0.3089 - val_accuracy: 0.8876
# Epoch 47/100
# 39/39 [==============================] - 0s 8ms/step - loss: 0.2836 - accuracy: 0.9176 - val_loss: 0.2949 - val_accuracy: 0.9105
# Epoch 48/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2796 - accuracy: 0.9233 - val_loss: 0.3203 - val_accuracy: 0.8876
# Epoch 49/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2829 - accuracy: 0.9135 - val_loss: 0.3087 - val_accuracy: 0.8876
# Epoch 50/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2708 - accuracy: 0.9167 - val_loss: 0.2915 - val_accuracy: 0.9048
# Epoch 51/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2599 - accuracy: 0.9290 - val_loss: 0.2751 - val_accuracy: 0.9219
# Epoch 52/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2578 - accuracy: 0.9273 - val_loss: 0.2720 - val_accuracy: 0.9143
# Epoch 53/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2512 - accuracy: 0.9339 - val_loss: 0.2697 - val_accuracy: 0.9181
# Epoch 54/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2547 - accuracy: 0.9290 - val_loss: 0.2703 - val_accuracy: 0.9238
# Epoch 55/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2535 - accuracy: 0.9224 - val_loss: 0.2713 - val_accuracy: 0.9067
# Epoch 56/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2460 - accuracy: 0.9331 - val_loss: 0.2616 - val_accuracy: 0.9238
# Epoch 57/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2426 - accuracy: 0.9298 - val_loss: 0.2574 - val_accuracy: 0.9200
# Epoch 58/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2440 - accuracy: 0.9306 - val_loss: 0.2876 - val_accuracy: 0.9162
# Epoch 59/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.2387 - accuracy: 0.9265 - val_loss: 0.2602 - val_accuracy: 0.9162
# Epoch 60/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2501 - accuracy: 0.9257 - val_loss: 0.2474 - val_accuracy: 0.9333
# Epoch 61/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.2284 - accuracy: 0.9339 - val_loss: 0.2691 - val_accuracy: 0.9048
# Epoch 62/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2333 - accuracy: 0.9282 - val_loss: 0.2512 - val_accuracy: 0.9257
# Epoch 63/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2244 - accuracy: 0.9306 - val_loss: 0.2752 - val_accuracy: 0.9181
# Epoch 64/100
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2175 - accuracy: 0.9306 - val_loss: 0.2398 - val_accuracy: 0.9314
# Epoch 65/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2137 - accuracy: 0.9412 - val_loss: 0.2323 - val_accuracy: 0.9352
# Epoch 66/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.2126 - accuracy: 0.9420 - val_loss: 0.2258 - val_accuracy: 0.9295
# Epoch 67/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2170 - accuracy: 0.9388 - val_loss: 0.2275 - val_accuracy: 0.9295
# Epoch 68/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2026 - accuracy: 0.9363 - val_loss: 0.2267 - val_accuracy: 0.9276
# Epoch 69/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.2006 - accuracy: 0.9461 - val_loss: 0.2275 - val_accuracy: 0.9295
# Epoch 70/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1991 - accuracy: 0.9445 - val_loss: 0.2255 - val_accuracy: 0.9352
# Epoch 71/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1942 - accuracy: 0.9461 - val_loss: 0.2318 - val_accuracy: 0.9238
# Epoch 72/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1932 - accuracy: 0.9437 - val_loss: 0.2187 - val_accuracy: 0.9352
# Epoch 73/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1875 - accuracy: 0.9478 - val_loss: 0.2179 - val_accuracy: 0.9276
# Epoch 74/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1917 - accuracy: 0.9429 - val_loss: 0.2288 - val_accuracy: 0.9200
# Epoch 75/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1816 - accuracy: 0.9518 - val_loss: 0.2371 - val_accuracy: 0.9162
# Epoch 76/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1881 - accuracy: 0.9510 - val_loss: 0.2227 - val_accuracy: 0.9295
# Epoch 77/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1809 - accuracy: 0.9478 - val_loss: 0.2205 - val_accuracy: 0.9352
# Epoch 78/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1875 - accuracy: 0.9437 - val_loss: 0.2125 - val_accuracy: 0.9390
# Epoch 79/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1768 - accuracy: 0.9494 - val_loss: 0.2027 - val_accuracy: 0.9467
# Epoch 80/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 0.9494 - val_loss: 0.2094 - val_accuracy: 0.9352
# Epoch 81/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1679 - accuracy: 0.9551 - val_loss: 0.2067 - val_accuracy: 0.9371
# Epoch 82/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1687 - accuracy: 0.9510 - val_loss: 0.2048 - val_accuracy: 0.9333
# Epoch 83/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1676 - accuracy: 0.9518 - val_loss: 0.1955 - val_accuracy: 0.9429
# Epoch 84/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1655 - accuracy: 0.9559 - val_loss: 0.1994 - val_accuracy: 0.9333
# Epoch 85/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1675 - accuracy: 0.9510 - val_loss: 0.1951 - val_accuracy: 0.9276
# Epoch 86/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1684 - accuracy: 0.9478 - val_loss: 0.1969 - val_accuracy: 0.9410
# Epoch 87/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1575 - accuracy: 0.9567 - val_loss: 0.1978 - val_accuracy: 0.9371
# Epoch 88/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.9576 - val_loss: 0.1930 - val_accuracy: 0.9390
# Epoch 89/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1543 - accuracy: 0.9616 - val_loss: 0.1884 - val_accuracy: 0.9390
# Epoch 90/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1573 - accuracy: 0.9551 - val_loss: 0.1853 - val_accuracy: 0.9448
# Epoch 91/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1542 - accuracy: 0.9600 - val_loss: 0.1820 - val_accuracy: 0.9390
# Epoch 92/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1473 - accuracy: 0.9616 - val_loss: 0.1811 - val_accuracy: 0.9448
# Epoch 93/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9559 - val_loss: 0.1951 - val_accuracy: 0.9314
# Epoch 94/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1468 - accuracy: 0.9600 - val_loss: 0.1880 - val_accuracy: 0.9410
# Epoch 95/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1510 - accuracy: 0.9608 - val_loss: 0.1777 - val_accuracy: 0.9467
# Epoch 96/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1433 - accuracy: 0.9633 - val_loss: 0.1734 - val_accuracy: 0.9486
# Epoch 97/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.9600 - val_loss: 0.1762 - val_accuracy: 0.9333
# Epoch 98/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.1390 - accuracy: 0.9641 - val_loss: 0.1852 - val_accuracy: 0.9448
# Epoch 99/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1445 - accuracy: 0.9584 - val_loss: 0.1883 - val_accuracy: 0.9295
# Epoch 100/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.9657 - val_loss: 0.1742 - val_accuracy: 0.9429
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 4ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 5ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 4ms/step
# Epoch 1/100
# 39/39 [==============================] - 1s 13ms/step - loss: 1.6947 - accuracy: 0.3069 - val_loss: 1.4905 - val_accuracy: 0.3695
# Epoch 2/100
# 39/39 [==============================] - 0s 6ms/step - loss: 1.3632 - accuracy: 0.5020 - val_loss: 1.2477 - val_accuracy: 0.5886
# Epoch 3/100
# 39/39 [==============================] - 0s 7ms/step - loss: 1.1598 - accuracy: 0.6237 - val_loss: 1.0893 - val_accuracy: 0.6533
# Epoch 4/100
# 39/39 [==============================] - 0s 6ms/step - loss: 1.0130 - accuracy: 0.6841 - val_loss: 0.9415 - val_accuracy: 0.7676
# Epoch 5/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.9074 - accuracy: 0.7420 - val_loss: 0.8619 - val_accuracy: 0.7657
# Epoch 6/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0
100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.4206 - accuracy: 0.8808 - val_loss: 0.4346 - val_accuracy: 0.8457
# Epoch 21/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.4140 - accuracy: 0.8800 - val_loss: 0.4599 - val_accuracy: 0.8514
# Epoch 22/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.4136 - accuracy: 0.8784 - val_loss: 0.4126 - val_accuracy: 0.8800
# Epoch 23/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.3904 - accuracy: 0.8865 - val_loss: 0.4085 - val_accuracy: 0.8724
# Epoch 24/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3784 - accuracy: 0.8931 - val_loss: 0.3908 - val_accuracy: 0.8895
# Epoch 25/100
# 39/39 [==============================] - 0s 4ms/step - loss: 0.3676 - accuracy: 0.8873 - val_loss: 0.4158 - val_accuracy: 0.8648
# Epoch 26/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3603 - accuracy: 0.8914 - val_loss: 0.4013 - val_accuracy: 0.8610
# Epoch 27/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3482 - accuracy: 0.8996 - val_loss: 0.3739 - val_accuracy: 0.8800
# Epoch 28/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3406 - accuracy: 0.9078 - val_loss: 0.3657 - val_accuracy: 0.8705
# Epoch 29/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3293 - accuracy: 0.9061 - val_loss: 0.3643 - val_accuracy: 0.8724
# Epoch 30/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3192 - accuracy: 0.9110 - val_loss: 0.3485 - val_accuracy: 0.8952
# Epoch 31/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3172 - accuracy: 0.9061 - val_loss: 0.3340 - val_accuracy: 0.8876
# Epoch 32/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3098 - accuracy: 0.9127 - val_loss: 0.3351 - val_accuracy: 0.8876
# Epoch 33/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2962 - accuracy: 0.9208 - val_loss: 0.3331 - val_accuracy: 0.8952
# Epoch 34/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2969 - accuracy: 0.9176 - val_loss: 0.3239 - val_accuracy: 0.8914
# Epoch 35/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2835 - accuracy: 0.9273 - val_loss: 0.3188 - val_accuracy: 0.9048
# Epoch 36/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2793 - accuracy: 0.9273 - val_loss: 0.3030 - val_accuracy: 0.9067
# Epoch 37/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2744 - accuracy: 0.9257 - val_loss: 0.3049 - val_accuracy: 0.9200
# Epoch 38/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2847 - accuracy: 0.9143 - val_loss: 0.3062 - val_accuracy: 0.9048
# Epoch 39/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2636 - accuracy: 0.9273 - val_loss: 0.3015 - val_accuracy: 0.9143
# Epoch 40/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2616 - accuracy: 0.9257 - val_loss: 0.2858 - val_accuracy: 0.8990
# Epoch 41/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2521 - accuracy: 0.9331 - val_loss: 0.2842 - val_accuracy: 0.9048
# Epoch 42/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2442 - accuracy: 0.9331 - val_loss: 0.2770 - val_accuracy: 0.9200
# Epoch 43/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2447 - accuracy: 0.9380 - val_loss: 0.2693 - val_accuracy: 0.9200
# Epoch 44/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2317 - accuracy: 0.9396 - val_loss: 0.2659 - val_accuracy: 0.9200
# Epoch 45/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2278 - accuracy: 0.9437 - val_loss: 0.2654 - val_accuracy: 0.9200
# Epoch 46/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2345 - accuracy: 0.9331 - val_loss: 0.2589 - val_accuracy: 0.9200
# Epoch 47/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2210 - accuracy: 0.9429 - val_loss: 0.2496 - val_accuracy: 0.9162
# Epoch 48/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2163 - accuracy: 0.9412 - val_loss: 0.2623 - val_accuracy: 0.9086
# Epoch 49/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2144 - accuracy: 0.9420 - val_loss: 0.2601 - val_accuracy: 0.9162
# Epoch 50/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9396 - val_loss: 0.2722 - val_accuracy: 0.9048
# Epoch 51/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2054 - accuracy: 0.9461 - val_loss: 0.2571 - val_accuracy: 0.9048
# Epoch 52/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2124 - accuracy: 0.9363 - val_loss: 0.2454 - val_accuracy: 0.9086
# Epoch 53/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1985 - accuracy: 0.9518 - val_loss: 0.2511 - val_accuracy: 0.9219
# Epoch 54/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2097 - accuracy: 0.9371 - val_loss: 0.2286 - val_accuracy: 0.9295
# Epoch 55/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1928 - accuracy: 0.9478 - val_loss: 0.2315 - val_accuracy: 0.9333
# Epoch 56/100
# 39/39 [==============================] - 0s 9ms/step - loss: 0.1885 - accuracy: 0.9535 - val_loss: 0.2241 - val_accuracy: 0.9390
# Epoch 57/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1948 - accuracy: 0.9380 - val_loss: 0.2241 - val_accuracy: 0.9276
# Epoch 58/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1854 - accuracy: 0.9502 - val_loss: 0.2185 - val_accuracy: 0.9295
# Epoch 59/100
# 39/39 [==============================] - 0s 9ms/step - loss: 0.1775 - accuracy: 0.9543 - val_loss: 0.2253 - val_accuracy: 0.9257
# Epoch 60/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1766 - accuracy: 0.9478 - val_loss: 0.2422 - val_accuracy: 0.9276
# Epoch 61/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1852 - accuracy: 0.9494 - val_loss: 0.2260 - val_accuracy: 0.9257
# Epoch 62/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1751 - accuracy: 0.9559 - val_loss: 0.2264 - val_accuracy: 0.9200
# Epoch 63/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1763 - accuracy: 0.9478 - val_loss: 0.2125 - val_accuracy: 0.9333
# Epoch 64/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1620 - accuracy: 0.9535 - val_loss: 0.2084 - val_accuracy: 0.9371
# Epoch 65/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1659 - accuracy: 0.9551 - val_loss: 0.2041 - val_accuracy: 0.9429
# Epoch 66/100
# 39/39 [==============================] - 0s 8ms/step - loss: 0.1589 - accuracy: 0.9600 - val_loss: 0.2006 - val_accuracy: 0.9314
# Epoch 67/100
# 39/39 [==============================] - 0s 9ms/step - loss: 0.1583 - accuracy: 0.9592 - val_loss: 0.2001 - val_accuracy: 0.9467
# Epoch 68/100
# 39/39 [==============================] - 0s 10ms/step - loss: 0.1550 - accuracy: 0.9600 - val_loss: 0.2219 - val_accuracy: 0.9200
# Epoch 69/100
# 39/39 [==============================] - 0s 8ms/step - loss: 0.1606 - accuracy: 0.9518 - val_loss: 0.2422 - val_accuracy: 0.9105
# Epoch 70/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1553 - accuracy: 0.9559 - val_loss: 0.2121 - val_accuracy: 0.9276
# Epoch 71/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1547 - accuracy: 0.9567 - val_loss: 0.2113 - val_accuracy: 0.9295
# Epoch 72/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1510 - accuracy: 0.9567 - val_loss: 0.2175 - val_accuracy: 0.9295
# Epoch 73/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1462 - accuracy: 0.9616 - val_loss: 0.2014 - val_accuracy: 0.9333
# Epoch 74/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1361 - accuracy: 0.9665 - val_loss: 0.1952 - val_accuracy: 0.9352
# Epoch 75/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1432 - accuracy: 0.9616 - val_loss: 0.1940 - val_accuracy: 0.9371
# Epoch 76/100
# 39/39 [==============================] - 0s 8ms/step - loss: 0.1322 - accuracy: 0.9690 - val_loss: 0.2047 - val_accuracy: 0.9295
# Epoch 77/100
# 39/39 [==============================] - 0s 10ms/step - loss: 0.1368 - accuracy: 0.9633 - val_loss: 0.1852 - val_accuracy: 0.9429
# Epoch 78/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1335 - accuracy: 0.9616 - val_loss: 0.1884 - val_accuracy: 0.9486
# Epoch 79/100
# 39/39 [==============================] - 0s 9ms/step - loss: 0.1387 - accuracy: 0.9649 - val_loss: 0.1885 - val_accuracy: 0.9352
# Epoch 80/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1310 - accuracy: 0.9690 - val_loss: 0.1859 - val_accuracy: 0.9410
# Epoch 81/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1227 - accuracy: 0.9714 - val_loss: 0.1950 - val_accuracy: 0.9410
# Epoch 82/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1285 - accuracy: 0.9600 - val_loss: 0.1976 - val_accuracy: 0.9333
# Epoch 83/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9673 - val_loss: 0.2167 - val_accuracy: 0.9238
# Epoch 84/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1292 - accuracy: 0.9624 - val_loss: 0.1772 - val_accuracy: 0.9390
# Epoch 85/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1185 - accuracy: 0.9731 - val_loss: 0.1761 - val_accuracy: 0.9410
# Epoch 86/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1154 - accuracy: 0.9706 - val_loss: 0.1933 - val_accuracy: 0.9276
# Epoch 87/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1242 - accuracy: 0.9698 - val_loss: 0.1753 - val_accuracy: 0.9429
# Epoch 88/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9624 - val_loss: 0.1837 - val_accuracy: 0.9410
# Epoch 89/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1239 - accuracy: 0.9641 - val_loss: 0.1782 - val_accuracy: 0.9390
# Epoch 90/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1239 - accuracy: 0.9657 - val_loss: 0.2004 - val_accuracy: 0.9410
# Epoch 91/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1164 - accuracy: 0.9665 - val_loss: 0.2309 - val_accuracy: 0.9200
# Epoch 92/100
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1322 - accuracy: 0.9616 - val_loss: 0.1912 - val_accuracy: 0.9333
# Epoch 93/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1120 - accuracy: 0.9706 - val_loss: 0.1665 - val_accuracy: 0.9524
# Epoch 94/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1107 - accuracy: 0.9706 - val_loss: 0.1691 - val_accuracy: 0.9410
# Epoch 95/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1109 - accuracy: 0.9706 - val_loss: 0.1705 - val_accuracy: 0.9410
# Epoch 96/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9706 - val_loss: 0.1621 - val_accuracy: 0.9448
# Epoch 97/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9763 - val_loss: 0.1796 - val_accuracy: 0.9448
# Epoch 98/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1065 - accuracy: 0.9698 - val_loss: 0.1643 - val_accuracy: 0.9467
# Epoch 99/100
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1078 - accuracy: 0.9690 - val_loss: 0.1610 - val_accuracy: 0.9448
# Epoch 100/100
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0953 - accuracy: 0.9780 - val_loss: 0.1578 - val_accuracy: 0.9486
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 3ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
#
# Best Average Accuracy: 0.9485714285714286
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
#
# Confusion Matrix:
# [[67  1  0  5  0  1  1]
#  [ 0 68  1  5  1  0  0]
#  [ 0  2 73  0  0  0  0]
#  [ 5  0  0 70  0  0  0]
#  [ 0  0  3  0 70  0  2]
#  [ 0  0  0  0  0 75  0]
#  [ 0  0  0  0  0  0 75]]
#
# Accuracy: 0.9485714285714286
#
# Precision: 0.9493785774628726
#
# Recall: 0.9485714285714286
#
# F1 Score: 0.9484996210431414
# ROC AUC score: 0.9970708994708994

# %% [markdown]
# *****

# %%
fig, ax = plt.subplots(figsize=(795/80, 835/80))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
cmap = mpl.colors.ListedColormap(['red','lightgreen','darkgreen','yellow','blue','lightyellow','gray'])
image = plt.imshow(features_chips_prediction_arr_Nadi_2013, cmap=cmap, extent=extent, interpolation='nearest')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos)+0.5)*(n_class_pos-1)/n_class_pos
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Urban', 'Crop/Grass', 'Trees', 'Bare', 'Water','Coastal','Wetland'])
plt.grid(False)
